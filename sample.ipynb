# %%
import torch
torch.__version__
# Out:
# '1.13.0+cu117'

# %%
from ivim_morph.infer import load_case, infer_from_data
import os
import torch 
import matplotlib.pyplot as plt
import numpy as np

path = '//tcmldrive/NogaK/fetal_lung_case'
device = 'cuda' if torch.cuda.is_available() else 'cpu'

data_path = os.path.join(path, 'Case709_data.pt')
seg_path = os.path.join(path, 'Case709_seg.pt')
signal, seg = load_case(data_path, seg_path, device=device)

bvalues = [0, 50, 100, 200, 400, 600]

Dp, D, f = infer_from_data(signal, seg, bvalues, device=device)
# Out:
# fitting case with 25 iterations...
# Training Progress:   0%|          | 0/25 [00:00<?, ?it/s]
# Training Progress:   8%|▊         | 2/25 [00:00<00:01, 12.11it/s]
# Iter 0 loss = 46.5011
# Training Progress: 100%|██████████| 25/25 [00:01<00:00, 12.71it/s]
# Finished fitting...

# %%
fig, ax = plt.subplots(1, 6, figsize=(15, 5))
for i in range(signal.shape[0]):
    ax[i].imshow(signal[i, :, :], cmap='gray')

# %%
plt.imshow(np.squeeze(D), cmap='gray')

# %%
plt.imshow(np.squeeze(f), cmap='gray')

# %%
plt.imshow(np.squeeze(Dp), cmap='gray')
